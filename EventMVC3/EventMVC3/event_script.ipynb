-- %% [markdown]
-- # [event]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [event]    Script Date: 01/11/46 06:28:57 ص ******/
CREATE DATABASE [event]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'event', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\event.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'event_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\event_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [event] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [event].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [event] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [event] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [event] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [event] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [event] SET ARITHABORT OFF 
GO
ALTER DATABASE [event] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [event] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [event] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [event] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [event] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [event] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [event] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [event] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [event] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [event] SET  ENABLE_BROKER 
GO
ALTER DATABASE [event] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [event] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [event] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [event] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [event] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [event] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [event] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [event] SET RECOVERY FULL 
GO
ALTER DATABASE [event] SET  MULTI_USER 
GO
ALTER DATABASE [event] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [event] SET DB_CHAINING OFF 
GO
ALTER DATABASE [event] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [event] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [event] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [event] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [event] SET QUERY_STORE = ON
GO
ALTER DATABASE [event] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[cardsPay]

-- %%
USE [event]
GO

-- %%
/****** Object:  Table [dbo].[cardsPay]    Script Date: 01/11/46 06:28:57 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cardsPay](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[numberOfCard] [int] NOT NULL,
	[expiryDate] [date] NOT NULL,
	[name] [varchar](max) NOT NULL,
	[cvv] [smallint] NOT NULL,
	[userId] [int] NOT NULL,
 CONSTRAINT [PK_cardsPay] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Comments]

-- %%
/****** Object:  Table [dbo].[Comments]    Script Date: 01/11/46 06:28:57 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Comments](
	[id] [bigint] IDENTITY(1,1) NOT NULL,
	[comment] [nvarchar](max) NOT NULL,
	[userId] [int] NOT NULL,
	[eventId] [int] NULL,
 CONSTRAINT [PK_Comments] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[eventCategory]

-- %%
/****** Object:  Table [dbo].[eventCategory]    Script Date: 01/11/46 06:28:57 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[eventCategory](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[categoryName] [nvarchar](50) NOT NULL,
	[icon] [varchar](max) NULL,
 CONSTRAINT [PK_eventCategory] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[events]

-- %%
/****** Object:  Table [dbo].[events]    Script Date: 01/11/46 06:28:57 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[events](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NOT NULL,
	[startDate] [date] NOT NULL,
	[finishDate] [date] NULL,
	[startTime] [time](7) NULL,
	[fineshTime] [time](7) NULL,
	[placeName] [nvarchar](max) NULL,
	[city] [nvarchar](50) NULL,
	[discription] [nvarchar](max) NOT NULL,
	[userId] [int] NULL,
	[category] [int] NOT NULL,
	[price] [int] NULL,
	[image] [nvarchar](max) NULL,
	[constraintAge] [nvarchar](50) NULL,
 CONSTRAINT [PK_events] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reservations]

-- %%
/****** Object:  Table [dbo].[Reservations]    Script Date: 01/11/46 06:28:57 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reservations](
	[idNumber] [int] NOT NULL,
	[bookingDate] [date] NOT NULL,
	[email] [varchar](max) NULL,
	[phoneNumber] [varchar](50) NULL,
	[eventId] [int] NOT NULL,
	[userId] [int] NOT NULL,
 CONSTRAINT [PK_Reservations] PRIMARY KEY CLUSTERED 
(
	[idNumber] ASC,
	[bookingDate] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 01/11/46 06:28:57 ص ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](max) NOT NULL,
	[email] [nvarchar](max) NOT NULL,
	[six] [nvarchar](10) NULL,
	[userName] [varchar](50) NOT NULL,
	[password] [varchar](50) NOT NULL,
 CONSTRAINT [PK_User] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_cardsPay_User]

-- %%
ALTER TABLE [dbo].[cardsPay]  WITH CHECK ADD  CONSTRAINT [FK_cardsPay_User] FOREIGN KEY([userId])
REFERENCES [dbo].[User] ([id])
GO
ALTER TABLE [dbo].[cardsPay] CHECK CONSTRAINT [FK_cardsPay_User]
GO

-- %% [markdown]
-- # [FK_Comments_events]

-- %%
ALTER TABLE [dbo].[Comments]  WITH CHECK ADD  CONSTRAINT [FK_Comments_events] FOREIGN KEY([eventId])
REFERENCES [dbo].[events] ([id])
GO
ALTER TABLE [dbo].[Comments] CHECK CONSTRAINT [FK_Comments_events]
GO

-- %% [markdown]
-- # [FK_Comments_User]

-- %%
ALTER TABLE [dbo].[Comments]  WITH CHECK ADD  CONSTRAINT [FK_Comments_User] FOREIGN KEY([userId])
REFERENCES [dbo].[User] ([id])
GO
ALTER TABLE [dbo].[Comments] CHECK CONSTRAINT [FK_Comments_User]
GO

-- %% [markdown]
-- # [FK_events_eventCategory]

-- %%
ALTER TABLE [dbo].[events]  WITH CHECK ADD  CONSTRAINT [FK_events_eventCategory] FOREIGN KEY([category])
REFERENCES [dbo].[eventCategory] ([id])
GO
ALTER TABLE [dbo].[events] CHECK CONSTRAINT [FK_events_eventCategory]
GO

-- %% [markdown]
-- # [FK_events_User]

-- %%
ALTER TABLE [dbo].[events]  WITH CHECK ADD  CONSTRAINT [FK_events_User] FOREIGN KEY([userId])
REFERENCES [dbo].[User] ([id])
GO
ALTER TABLE [dbo].[events] CHECK CONSTRAINT [FK_events_User]
GO

-- %% [markdown]
-- # [FK_Reservations_events]

-- %%
ALTER TABLE [dbo].[Reservations]  WITH CHECK ADD  CONSTRAINT [FK_Reservations_events] FOREIGN KEY([eventId])
REFERENCES [dbo].[events] ([id])
GO
ALTER TABLE [dbo].[Reservations] CHECK CONSTRAINT [FK_Reservations_events]
GO

-- %% [markdown]
-- # [FK_Reservations_User]

-- %%
ALTER TABLE [dbo].[Reservations]  WITH CHECK ADD  CONSTRAINT [FK_Reservations_User] FOREIGN KEY([userId])
REFERENCES [dbo].[User] ([id])
GO
ALTER TABLE [dbo].[Reservations] CHECK CONSTRAINT [FK_Reservations_User]
GO

-- %% [markdown]
-- # [event]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [event] SET  READ_WRITE 
GO
